# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %cd /home/wallar/projects/nyc-taxi-analysis/
# Out:
# /home/wallar/projects/nyc-taxi-analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scripts import common
from scripts import plot_metrics
sns.set_context("poster", font_scale=1.5)
common.get_metrics_day_new_data(3000, 4, 300, 200, 2)
# Out:
#       index  active_taxis  empty_moving_to_pickup  empty_rebalancing  \
# 0         0           0.0                     320                  0
# 1         1          50.0                     323                  0
# 2         2         105.0                     352                  0
# 3         3         176.0                     317                  0
# 4         4         224.0                     368                  0
# 5         5         309.0                     340                  0
# 6         6         366.0                     392                  0
# 7         7         449.0                     343                  0
# 8         8         514.0                     369                  0
# 9         9         573.0                     343                  0
# 10       10         628.0                     362                  0
# 11       11         681.0                     332                  0
# 12       12         724.0                     344                  0
# ...

# %%
big_d = plot_metrics.get_big_d()

# %%
plot_metrics.make_pred_plots(big_d)
# Out:
# mean_waiting_time:   0%|          | 0/15 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2db8ff285918> in <module>()
# ----> 1 plot_metrics.make_pred_plots(big_d)
#
# /home/wallar/projects/nyc-taxi-analysis/scripts/plot_metrics.py in make_pred_plots(big_d)
#      74         fig.set_size_inches(13, 10)
#      75         ax = sns.pointplot(x="n_vehicles", y=field, hue="predictions",
# ---> 76                            data=big_d, palette=clrs)
#      77         ax.set_ylabel(prettify(field))
#      78         ax.set_xlabel("Number of Vehicles")
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, ax, **kwargs)
#    3009                             estimator, ci, n_boot, units,
# ...

# %%
fig, axarr = plt.subplots(1, 2, figsize=(15, 8))
sns.pointplot(x="predictions", y="mean_travel_delay", hue="n_vehicles", data=df, ax=axarr[0])
sns.pointplot(x="predictions", y="mean_waiting_time", hue="n_vehicles", data=df, ax=axarr[1])
ylabels = ["Mean Travel Delay", "Mean Waiting Time"]
for ax, yl in zip(axarr, ylabels):
    ax.set_ylabel(yl)
    ax.legend().remove()

# %%
import numpy as np
import sklearn.mixture as mix
trans = np.load("data/freqs.npy")

# %%
ts = list()
pick, drop = 148, 224
fig, axarr = plt.subplots(7, 1, figsize=(15, 20), sharex=True)
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
for day in xrange(7):
    axarr[day].plot(trans[..., day].sum(axis=2))
    axarr[day].set_title(days[day])
